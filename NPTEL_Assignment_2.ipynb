# %% [markdown]
# <a href="https://colab.research.google.com/github/varshini-dev/gitsetgo/blob/minebranch/NPTEL_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook for Week 2 Assignment**

# %% [markdown]
# ## Instructions:
# 1. Run the cells in the order they appear.
# 2. Refer to the question number mentioned above each cell.
# 2. Input your code in the designated area based on the description provided in the question.
#
# Hint: You may use the IBM Quantum Composer to understand the Qiskit code for implementing various gates.

# %%
# !pip install qiskit

# %% [markdown]
# **Question 6**

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector, DensityMatrix
from qiskit.visualization import plot_state_city
import matplotlib.pyplot as plt

# Write the code for the circuit described in Question 6 :
#=======================================================================================================================
qc = QuantumCircuit(3)

# Create GHZ state
qc.h(0)
qc.cx(0, 1)
qc.cx(0, 2)

#=======================================================================================================================

print(qc.draw())

state = Statevector(qc)
rho = DensityMatrix(state)
plot_state_city(rho)
plt.show()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■────■──
#      └───┘┌─┴─┐  │
# q_1: ─────┤ X ├──┼──
#           └───┘┌─┴─┐
# q_2: ──────────┤ X ├
#                └───┘

# %% [markdown]
# **Question 7**

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
import numpy as np

# Write the code for the circuit described in Question 7 :
#=======================================================================================================================
qc = QuantumCircuit(2)

qc.h(0)
qc.h(1)

qc.cx(0, 1)

qc.h(0)

#=======================================================================================================================
print(qc.draw())

final_state = Statevector(qc)
final_state.draw('latex')
# Out:
#      ┌───┐     ┌───┐
# q_0: ┤ H ├──■──┤ H ├
#      ├───┤┌─┴─┐└───┘
# q_1: ┤ H ├┤ X ├─────
#      └───┘└───┘
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |10\rangle$$

# %% [markdown]
# **Question 8**

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
import numpy as np


# Write the code for the circuit described in Question 8 :
#=======================================================================================================================
qc = QuantumCircuit(3)

qc.ry(2 * np.pi / 3, 0)

qc.cx(0, 1)
#=======================================================================================================================

print(qc.draw())
final_state = Statevector(qc)
final_state.draw('latex')
# Out:
#      ┌──────────┐
# q_0: ┤ Ry(2π/3) ├──■──
#      └──────────┘┌─┴─┐
# q_1: ────────────┤ X ├
#                  └───┘
# q_2: ─────────────────
# $$\frac{1}{2} |000\rangle+\frac{\sqrt{3}}{2} |011\rangle$$
